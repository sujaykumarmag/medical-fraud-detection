# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
dmepos = pd.read_csv("labelled_data/DMEPOS/features/dmepos_features_data.csv")
part_b = pd.read_csv("labelled_data/part_B/features/partb_features_data.csv")
part_d = pd.read_csv("labelled_data/part_D/features/partd_features_data.csv")

# %%
merged_partB_partD = pd.merge(part_b, part_d, left_on='Rndrng_NPI', right_on='PRSCRBR_NPI', how='inner')
combined = pd.merge(merged_partB_partD, dmepos, left_on='Rndrng_NPI', right_on='Rfrg_NPI', how='inner')

# %%
combined
# Out:
#         Unnamed: 0_x  Rndrng_NPI                     Rndrng_Prvdr_Type  \
# 0                  5  1003000522                       Family Practice
# 1                  6  1003000530                     Internal Medicine
# 2                 14  1003000902                       Family Practice
# 3                 22  1003001363                       Pain Management
# 4                 23  1003001371  Physical Medicine and Rehabilitation
# ...              ...         ...                                   ...
# 211785       1161520  1992997647                       Family Practice
# 211786       1161529  1992998645                     Internal Medicine
# 211787       1161532  1992998736                       Family Practice
# 211788       1161534  1992999122                     Internal Medicine
# 211789       1161537  1992999551                     Internal Medicine
#
#        Rndrng_Prvdr_Gndr  Tot_Srvcs  Tot_Benes_x  Tot_Sbmtd_Chrg  \
# ...

# %%
combined["Fraud"].value_counts()
# Out:
# 0    211752
# 1        38
# Name: Fraud, dtype: int64

# %%
combined = combined.dropna(axis=0)

# %%
combined["FraudType"].value_counts()
# Out:
# 0            211752
# 1128a1           12
# 1128b4           10
# 1128b7            5
# 1128a1            5
# 1128a4            3
# 1128a3            2
# 1128a2            1
# Name: FraudType, dtype: int64

# %%
combined = combined.drop(["Fraud_y","FraudType_y","Fraud_x","FraudType_x","Rfrg_Prvdr_Gndr","Rfrg_Prvdr_Type","Prscrbr_Type_src"],axis=1)

# %%
combined["FraudType"].value_counts()
# Out:
# 0            211752
# 1128a1           12
# 1128b4           10
# 1128b7            5
# 1128a1            5
# 1128a4            3
# 1128a3            2
# 1128a2            1
# Name: FraudType, dtype: int64

# %%
combined.to_csv("labelled_data/combined/features/combined_features_data.csv")
