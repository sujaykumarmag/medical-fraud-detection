# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../labelled_data/DMEPOS/processed_dmepos.csv")

# %%
df
# Out:
#         Unnamed: 0    Rfrg_NPI  Rfrg_Prvdr_Crdntls  Rfrg_Prvdr_Gndr  \
# 0                0  1003000126                2362              0.0
# 1                1  1003000522                3017              0.0
# 2                2  1003000530                1629              1.0
# 3                3  1003000597                2684              0.0
# 4                4  1003000738                4511              1.0
# ...            ...         ...                 ...              ...
# 383452      383483  1992998645                3017              1.0
# 383453      383484  1992998736                2362              0.0
# 383454      383485  1992999122                1186              0.0
# 383455      383486  1992999551                2362              1.0
# 383456      383487  1992999874                5465              1.0
#
#         Rfrg_Prvdr_Type  Rfrg_Prvdr_Type_Flag  Tot_Suplrs  \
# 0                    44                   1.0           8
# ...

# %%
df = df.drop(["Unnamed: 0"],axis=1)

# %%
from miceforest import ImputationKernel

mice_kernel = ImputationKernel(
data = df,
random_state = 2023
)

# %%
mice_kernel.mice()
mice_imputation = mice_kernel.complete_data()
mice_imputation.head()
# Out:
#      Rfrg_NPI  Rfrg_Prvdr_Crdntls  Rfrg_Prvdr_Gndr  Rfrg_Prvdr_Type  \
# 0  1003000126                2362              0.0               44
# 1  1003000522                3017              0.0               26
# 2  1003000530                1629              1.0               44
# 3  1003000597                2684              0.0              117
# 4  1003000738                4511              1.0               87
#
#    Rfrg_Prvdr_Type_Flag  Tot_Suplrs  Tot_Suplr_HCPCS_Cds  Tot_Suplr_Benes  \
# 0                   1.0           8                    7             11.0
# 1                   1.0          28                   47             33.0
# 2                   1.0          11                   44             19.0
# 3                   1.0           5                   12             23.0
# 4                   1.0           1                    1             13.0
#
#    Tot_Suplr_Clms  Tot_Suplr_Srvcs  ...  Bene_CC_Hyplpdma_Pct  \
# ...

# %%
mice_imputation.dropna(axis=0)
# Out:
#           Rfrg_NPI  Rfrg_Prvdr_Crdntls  Rfrg_Prvdr_Gndr  Rfrg_Prvdr_Type  \
# 0       1003000126                2362              0.0               44
# 1       1003000522                3017              0.0               26
# 2       1003000530                1629              1.0               44
# 3       1003000597                2684              0.0              117
# 4       1003000738                4511              1.0               87
# ...            ...                 ...              ...              ...
# 383452  1992998645                3017              1.0               44
# 383453  1992998736                2362              0.0               26
# 383454  1992999122                1186              0.0               44
# 383455  1992999551                2362              1.0               44
# 383456  1992999874                5465              1.0               44
#
#         Rfrg_Prvdr_Type_Flag  Tot_Suplrs  Tot_Suplr_HCPCS_Cds  \
# ...

# %%
mice_imputation.to_csv("../../labelled_data/DMEPOS/imputed_dmepos.csv")
