# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv("labelled_data/part_D/partd_data.csv")

# %%
df
# Out:
#          Unnamed: 0  PRSCRBR_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name  \
# 0                 0   1003000126             Enkeshafi            Ardalan
# 1                 1   1003000142                Khalil             Rashid
# 2                 2   1003000167               Escobar              Julio
# 3                 3   1003000175         Reyes-Vasquez            Belinda
# 4                 4   1003000282             Blakemore              Rosie
# ...             ...          ...                   ...                ...
# 1255119     1255170   1992999569                  Yuen              Jenny
# 1255120     1255171   1992999650                  Yong              Wayne
# 1255121     1255172   1992999759               Soriano               Dino
# 1255122     1255173   1992999825             Deschenes           Geoffrey
# 1255123     1255174   1992999874                 Joffe          Gabriella
#
#         Prscrbr_MI   Prscrbr_Crdntls Prscrbr_Gndr Prscrbr_Ent_Cd  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PRSCRBR_NPI', 'Prscrbr_Last_Org_Name',
#        'Prscrbr_First_Name', 'Prscrbr_MI', 'Prscrbr_Crdntls', 'Prscrbr_Gndr',
#        'Prscrbr_Ent_Cd', 'Prscrbr_St1', 'Prscrbr_St2', 'Prscrbr_City',
#        'Prscrbr_State_Abrvtn', 'Prscrbr_State_FIPS', 'Prscrbr_zip5',
#        'Prscrbr_RUCA', 'Prscrbr_RUCA_Desc', 'Prscrbr_Cntry', 'Prscrbr_Type',
#        'Prscrbr_Type_src', 'Tot_Clms', 'Tot_30day_Fills', 'Tot_Drug_Cst',
#        'Tot_Day_Suply', 'Tot_Benes', 'GE65_Sprsn_Flag', 'GE65_Tot_Clms',
#        'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst', 'GE65_Tot_Day_Suply',
#        'GE65_Bene_Sprsn_Flag', 'GE65_Tot_Benes', 'Brnd_Sprsn_Flag',
#        'Brnd_Tot_Clms', 'Brnd_Tot_Drug_Cst', 'Gnrc_Sprsn_Flag',
#        'Gnrc_Tot_Clms', 'Gnrc_Tot_Drug_Cst', 'Othr_Sprsn_Flag',
#        'Othr_Tot_Clms', 'Othr_Tot_Drug_Cst', 'MAPD_Sprsn_Flag',
#        'MAPD_Tot_Clms', 'MAPD_Tot_Drug_Cst', 'PDP_Sprsn_Flag', 'PDP_Tot_Clms',
# ...

# %%
df["GE65_Tot_Drug_Cst"]
# Out:
# 0          17117.40
# 1          18262.43
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1255119         NaN
# 1255120         NaN
# 1255121     4832.38
# 1255122    10090.12
# 1255123    11725.70
# Name: GE65_Tot_Drug_Cst, Length: 1255124, dtype: float64

# %%
df = df[['PRSCRBR_NPI','Prscrbr_Type','Tot_Clms', 'Tot_30day_Fills', 'Tot_Drug_Cst','Tot_Day_Suply', 'Tot_Benes', 'GE65_Tot_Clms','GE65_Tot_30day_Fills', 
    'GE65_Tot_Drug_Cst', 'GE65_Tot_Day_Suply', 'GE65_Tot_Benes', 'Brnd_Tot_Clms', 'Brnd_Tot_Drug_Cst', 'Gnrc_Tot_Clms', 
    'Gnrc_Tot_Drug_Cst','Othr_Tot_Clms','Othr_Tot_Drug_Cst', 'MAPD_Tot_Clms', 'MAPD_Tot_Drug_Cst', 'PDP_Tot_Clms','PDP_Tot_Drug_Cst', 
    'LIS_Tot_Clms', 'LIS_Drug_Cst','NonLIS_Tot_Clms','NonLIS_Drug_Cst','Opioid_Tot_Clms', 'Opioid_Tot_Drug_Cst', 'Opioid_Tot_Suply',
    'Opioid_Tot_Benes', 'Opioid_LA_Tot_Clms','Opioid_LA_Tot_Drug_Cst', 'Opioid_LA_Tot_Suply', 'Opioid_LA_Tot_Benes','Antbtc_Tot_Clms', 
    'Antbtc_Tot_Drug_Cst','Antbtc_Tot_Benes', 'Antpsyct_GE65_Tot_Clms', 'Antpsyct_GE65_Tot_Drug_Cst','Antpsyct_GE65_Tot_Benes','Fraud']]

# %%
df
# Out:
#          PRSCRBR_NPI        Prscrbr_Type  Tot_Clms  Tot_30day_Fills  \
# 0         1003000126   Internal Medicine       324       369.800000
# 1         1003000142      Anesthesiology      1992      2145.666667
# 2         1003000167             Dentist        57        57.700000
# 3         1003000175             Dentist        18        18.000000
# 4         1003000282  Nurse Practitioner        37        47.000000
# ...              ...                 ...       ...              ...
# 1255119   1992999569           Optometry        40        80.666667
# 1255120   1992999650             Dentist        72        73.200000
# 1255121   1992999759  Nurse Practitioner        47        90.466667
# 1255122   1992999825      Otolaryngology       249       291.066667
# 1255123   1992999874   Internal Medicine       274       290.633333
#
#          Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes  GE65_Tot_Clms  \
# 0            20606.08           8621      106.0          277.0
# ...

# %%
df.dtypes
# Out:
# PRSCRBR_NPI                     int64
# Prscrbr_Type                   object
# Tot_Clms                        int64
# Tot_30day_Fills               float64
# Tot_Drug_Cst                  float64
# Tot_Day_Suply                   int64
# Tot_Benes                     float64
# GE65_Tot_Clms                 float64
# GE65_Tot_30day_Fills          float64
# GE65_Tot_Drug_Cst             float64
# GE65_Tot_Day_Suply            float64
# GE65_Tot_Benes                float64
# Brnd_Tot_Clms                 float64
# Brnd_Tot_Drug_Cst             float64
# Gnrc_Tot_Clms                 float64
# Gnrc_Tot_Drug_Cst             float64
# Othr_Tot_Clms                 float64
# Othr_Tot_Drug_Cst             float64
# MAPD_Tot_Clms                 float64
# MAPD_Tot_Drug_Cst             float64
# PDP_Tot_Clms                  float64
# PDP_Tot_Drug_Cst              float64
# LIS_Tot_Clms                  float64
# LIS_Drug_Cst                  float64
# NonLIS_Tot_Clms               float64
# ...

# %%
print(df["Tot_Clms"].isnull().sum())
print(df["Tot_30day_Fills"].isnull().sum())
print(df["Tot_Drug_Cst"].isnull().sum())
print(df["Tot_Day_Suply"].isnull().sum())
print("-------------------------------------------------")
print(df["Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["GE65_Tot_Clms"].isnull().sum())
print(df["GE65_Tot_30day_Fills"].isnull().sum())
print(df["GE65_Tot_Drug_Cst"].isnull().sum())
print(df["GE65_Tot_Day_Suply"].isnull().sum())
print(df["GE65_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Brnd_Tot_Clms"].isnull().sum())
print(df["Brnd_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Gnrc_Tot_Clms"].isnull().sum())
print(df["Gnrc_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Othr_Tot_Clms"].isnull().sum())
print(df["Othr_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["MAPD_Tot_Clms"].isnull().sum())
print(df["MAPD_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["PDP_Tot_Clms"].isnull().sum())
print(df["PDP_Tot_Drug_Cst"].isnull().sum())
print(df["LIS_Tot_Clms"].isnull().sum())
print(df["LIS_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_Tot_Clms"].isnull().sum())
print(df["Opioid_Tot_Drug_Cst"].isnull().sum())
print(df["Opioid_Tot_Suply"].isnull().sum())
print(df["Opioid_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_LA_Tot_Clms"].isnull().sum())
print(df["Opioid_LA_Tot_Drug_Cst"].isnull().sum())
print(df["Opioid_LA_Tot_Suply"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Antbtc_Tot_Clms"].isnull().sum())
print(df["Antbtc_Tot_Drug_Cst"].isnull().sum())
print(df["Antbtc_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Antpsyct_GE65_Tot_Clms"].isnull().sum())
print(df["Antpsyct_GE65_Tot_Drug_Cst"].isnull().sum())
print(df["Antpsyct_GE65_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# -------------------------------------------------
# 142956
# -------------------------------------------------
# 294227
# 294227
# 294227
# 294227
# 592000
# -------------------------------------------------
# 543484
# 543484
# -------------------------------------------------
# 30172
# 30172
# -------------------------------------------------
# 538251
# 538251
# -------------------------------------------------
# 231297
# 231297
# -------------------------------------------------
# 231297
# 231297
# 266730
# 266730
# -------------------------------------------------
# 347133
# 347133
# 347133
# 523631
# -------------------------------------------------
# 432770
# 432770
# 432770
# 651650
# -------------------------------------------------
# 373592
# 373592
# 501293
# -------------------------------------------------
# 459981
# 459981
# 797381
# -------------------------------------------------
# 651650
# 651650
# 651650
# 651650

# %% [markdown]
# ## Finding where all the major columns are NULL

# %%
x = len(df)
y = len(df.columns)
all_nan1 = []
for i in range(x):
    if df.iloc[i].isnull().sum()>=34:
        all_nan1.append(i)

# %%
len(all_nan1)
# Out:
# 121

# %% [markdown]
# ## Dropping all 121 records from the dataframe and all those records are non-fraud

# %%
all_nan_df = []
for i in all_nan1:
    df = df.drop(i,axis=0)
    all_nan_df.append(df.iloc[i])

# %%
 pd.DataFrame(all_nan_df)
# Out:
#          PRSCRBR_NPI                                       Prscrbr_Type  \
# 8473      1003840505                            Obstetrics & Gynecology
# 33755     1023397544                                            Dentist
# 40698     1033188453                                            Dentist
# 54403     1043326911                                         Psychiatry
# 73843     1053852566  Student in an Organized Health Care Education/...
# ...              ...                                                ...
# 1199409   1952601312                                           Podiatry
# 1212370   1962672584                                    Family Practice
# 1232399   1982149878                                 Nurse Practitioner
# 1245075   1992157606                                 Nurse Practitioner
# 1246827   1992268452  Student in an Organized Health Care Education/...
#
#          Tot_Clms  Tot_30day_Fills  Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes  \
# ...

# %%
all_nan_df = pd.DataFrame(all_nan_df)

# %%
all_nan_df.iloc[2].isnull().sum()
# Out:
# 12

# %%
all_nan_df["Fraud"].value_counts()
# Out:
# 0.0    121
# Name: Fraud, dtype: int64

# %%
df
# Out:
#          PRSCRBR_NPI        Prscrbr_Type  Tot_Clms  Tot_30day_Fills  \
# 0         1003000126   Internal Medicine       324       369.800000
# 1         1003000142      Anesthesiology      1992      2145.666667
# 2         1003000167             Dentist        57        57.700000
# 3         1003000175             Dentist        18        18.000000
# 4         1003000282  Nurse Practitioner        37        47.000000
# ...              ...                 ...       ...              ...
# 1255119   1992999569           Optometry        40        80.666667
# 1255120   1992999650             Dentist        72        73.200000
# 1255121   1992999759  Nurse Practitioner        47        90.466667
# 1255122   1992999825      Otolaryngology       249       291.066667
# 1255123   1992999874   Internal Medicine       274       290.633333
#
#          Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes  GE65_Tot_Clms  \
# 0            20606.08           8621      106.0          277.0
# ...

# %%
print(df["Tot_Clms"].isnull().sum())
print(df["Tot_30day_Fills"].isnull().sum())
print(df["Tot_Drug_Cst"].isnull().sum())
print(df["Tot_Day_Suply"].isnull().sum())
print("-------------------------------------------------")
print(df["Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["GE65_Tot_Clms"].isnull().sum())
print(df["GE65_Tot_30day_Fills"].isnull().sum())
print(df["GE65_Tot_Drug_Cst"].isnull().sum())
print(df["GE65_Tot_Day_Suply"].isnull().sum())
print(df["GE65_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Brnd_Tot_Clms"].isnull().sum())
print(df["Brnd_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Gnrc_Tot_Clms"].isnull().sum())
print(df["Gnrc_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Othr_Tot_Clms"].isnull().sum())
print(df["Othr_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["MAPD_Tot_Clms"].isnull().sum())
print(df["MAPD_Tot_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["PDP_Tot_Clms"].isnull().sum())
print(df["PDP_Tot_Drug_Cst"].isnull().sum())
print(df["LIS_Tot_Clms"].isnull().sum())
print(df["LIS_Drug_Cst"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_Tot_Clms"].isnull().sum())
print(df["Opioid_Tot_Drug_Cst"].isnull().sum())
print(df["Opioid_Tot_Suply"].isnull().sum())
print(df["Opioid_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_LA_Tot_Clms"].isnull().sum())
print(df["Opioid_LA_Tot_Drug_Cst"].isnull().sum())
print(df["Opioid_LA_Tot_Suply"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Antbtc_Tot_Clms"].isnull().sum())
print(df["Antbtc_Tot_Drug_Cst"].isnull().sum())
print(df["Antbtc_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Antpsyct_GE65_Tot_Clms"].isnull().sum())
print(df["Antpsyct_GE65_Tot_Drug_Cst"].isnull().sum())
print(df["Antpsyct_GE65_Tot_Benes"].isnull().sum())
print("-------------------------------------------------")
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
print(df["Opioid_LA_Tot_Benes"].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# -------------------------------------------------
# 142835
# -------------------------------------------------
# 294106
# 294106
# 294106
# 294106
# 591879
# -------------------------------------------------
# 543363
# 543363
# -------------------------------------------------
# 30051
# 30051
# -------------------------------------------------
# 538130
# 538130
# -------------------------------------------------
# 231176
# 231176
# -------------------------------------------------
# 231176
# 231176
# 266609
# 266609
# -------------------------------------------------
# 347012
# 347012
# 347012
# 523510
# -------------------------------------------------
# 432649
# 432649
# 432649
# 651529
# -------------------------------------------------
# 373471
# 373471
# 501172
# -------------------------------------------------
# 459860
# 459860
# 797260
# -------------------------------------------------
# 651529
# 651529
# 651529
# 651529

# %% [markdown]
# ## Now, we divide accordingly

# %% [markdown]
# ## First GDRC coz we have less

# %%
print(df["Gnrc_Tot_Clms"].isnull().sum())
print(df["Gnrc_Tot_Drug_Cst"].isnull().sum())
# Out:
# 30051
# 30051

# %%
gnrc_nan = []
no_gnrc = []
for i in range(len(df)):
    if(pd.isnull(df.iloc[i].Gnrc_Tot_Clms) == True and pd.isnull(df.iloc[i].Gnrc_Tot_Drug_Cst)):
        gnrc_nan.append(df.iloc[i])
    else:
        no_gnrc.append(df.iloc[i])

# %%
gnrc_nan = pd.DataFrame(gnrc_nan)
no_gnrc = pd.DataFrame(no_gnrc)

# %%
print(len(gnrc_nan))
gnrc_nan["Fraud"].value_counts()
# Out:
# 30051
# 0.0    30001
# 1.0       50
# Name: Fraud, dtype: int64

# %%
df.drop("Prscrbr_Type",axis=1).corr()
# Out:
#                             PRSCRBR_NPI  Tot_Clms  Tot_30day_Fills  \
# PRSCRBR_NPI                    1.000000 -0.000505        -0.000354
# Tot_Clms                      -0.000505  1.000000         0.953939
# Tot_30day_Fills               -0.000354  0.953939         1.000000
# Tot_Drug_Cst                   0.000972  0.543884         0.521138
# Tot_Day_Suply                 -0.000343  0.919410         0.991127
# Tot_Benes                      0.001489  0.501186         0.476152
# GE65_Tot_Clms                 -0.000481  0.980677         0.951925
# GE65_Tot_30day_Fills          -0.000356  0.923330         0.989000
# GE65_Tot_Drug_Cst              0.001504  0.537388         0.528775
# GE65_Tot_Day_Suply            -0.000353  0.886105         0.978563
# GE65_Tot_Benes                 0.001826  0.445367         0.423123
# Brnd_Tot_Clms                  0.000153  0.749965         0.668105
# Brnd_Tot_Drug_Cst             -0.000071  0.460074         0.436305
# ...

# %%
gnrc_nan
# Out:
#          PRSCRBR_NPI          Prscrbr_Type  Tot_Clms  Tot_30day_Fills  \
# 55        1003004128     Internal Medicine        43        59.933333
# 72        1003005745             Neurology        23        25.000000
# 181       1003012022     Pulmonary Disease       169       204.766667
# 217       1003013301               Dentist        11        13.600000
# 273       1003015553  Diagnostic Radiology        12        12.000000
# ...              ...                   ...       ...              ...
# 1254827   1992979322   Physician Assistant        11        11.000000
# 1254956   1992989271               Dentist        15        15.000000
# 1254973   1992990360             Optometry        12        28.666667
# 1254995   1992991335            Specialist        12        24.900000
# 1255092   1992997969             Optometry        19        27.000000
#
#          Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes  GE65_Tot_Clms  \
# ...

# %%
print(len(no_gnrc))
no_gnrc["Fraud"].value_counts()
# Out:
# 1224952
# 0.0    1223508
# 1.0       1444
# Name: Fraud, dtype: int64

# %%
gnrc_nan.drop(["Gnrc_Tot_Clms","Gnrc_Tot_Drug_Cst"],axis=1)
# Out:
#          PRSCRBR_NPI          Prscrbr_Type  Tot_Clms  Tot_30day_Fills  \
# 55        1003004128     Internal Medicine        43        59.933333
# 72        1003005745             Neurology        23        25.000000
# 181       1003012022     Pulmonary Disease       169       204.766667
# 217       1003013301               Dentist        11        13.600000
# 273       1003015553  Diagnostic Radiology        12        12.000000
# ...              ...                   ...       ...              ...
# 1254827   1992979322   Physician Assistant        11        11.000000
# 1254956   1992989271               Dentist        15        15.000000
# 1254973   1992990360             Optometry        12        28.666667
# 1254995   1992991335            Specialist        12        24.900000
# 1255092   1992997969             Optometry        19        27.000000
#
#          Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes  GE65_Tot_Clms  \
# ...

# %%
gnrc_nan.columns
# Out:
# Index(['PRSCRBR_NPI', 'Prscrbr_Type', 'Tot_Clms', 'Tot_30day_Fills',
#        'Tot_Drug_Cst', 'Tot_Day_Suply', 'Tot_Benes', 'GE65_Tot_Clms',
#        'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst', 'GE65_Tot_Day_Suply',
#        'GE65_Tot_Benes', 'Brnd_Tot_Clms', 'Brnd_Tot_Drug_Cst', 'Gnrc_Tot_Clms',
#        'Gnrc_Tot_Drug_Cst', 'Othr_Tot_Clms', 'Othr_Tot_Drug_Cst',
#        'MAPD_Tot_Clms', 'MAPD_Tot_Drug_Cst', 'PDP_Tot_Clms',
#        'PDP_Tot_Drug_Cst', 'LIS_Tot_Clms', 'LIS_Drug_Cst', 'NonLIS_Tot_Clms',
#        'NonLIS_Drug_Cst', 'Opioid_Tot_Clms', 'Opioid_Tot_Drug_Cst',
#        'Opioid_Tot_Suply', 'Opioid_Tot_Benes', 'Opioid_LA_Tot_Clms',
#        'Opioid_LA_Tot_Drug_Cst', 'Opioid_LA_Tot_Suply', 'Opioid_LA_Tot_Benes',
#        'Antbtc_Tot_Clms', 'Antbtc_Tot_Drug_Cst', 'Antbtc_Tot_Benes',
#        'Antpsyct_GE65_Tot_Clms', 'Antpsyct_GE65_Tot_Drug_Cst',
#        'Antpsyct_GE65_Tot_Benes', 'Fraud'],
#       dtype='object')

# %%
gnrc_nan["Opioid_LA_Tot_Benes"].value_counts()
# Out:
# 0.0    6666
# Name: Opioid_LA_Tot_Benes, dtype: int64

# %%
gnrc_nan = gnrc_nan.drop(["Gnrc_Tot_Clms","Gnrc_Tot_Drug_Cst"],axis=1)

# %%
gnrc_nan.to_csv("labelled_data/part_D/no_gnrc.csv")

# %%
fraud_tot_ben = []
nf_tot_ben = []
for i in range(len(df)):
    if(pd.isnull(df.iloc[i].Tot_Benes)== True):
        if(df.iloc[i].Fraud == 1):
            fraud_tot_ben.append(i)
        else:
            nf_tot_ben.append(i)

# %%
len(fraud_tot_ben)
# Out:
# 243

# %%
len(nf_tot_ben)
# Out:
# 142592

# %%
fraud_tot = []
nf_tot = []
for i in range(len(df)):
    if pd.isnull(df.iloc[i].Tot_Clms)== True and pd.isnull(df.iloc[i].Tot_30day_Fills)== True and pd.isnull(df.iloc[i].Tot_Drug_Cst)== True and pd.isnull(df.iloc[i].Tot_Day_Suply)== True and pd.isnull(df.iloc[i].Tot_Benes)== True:
        if(df.iloc[i].Fraud == 1):
            fraud_tot.append(i)
        else:
            nf_tot.append(i)

# %%
len(fraud_tot)
# Out:
# 0

# %%
len(nf_tot)
# Out:
# 0

# %% [markdown]
# ## We see that the Tot_Benes is inconsistent with Tot so, we now check with every other column

# %% [markdown]
# ### With Tot_Benes

# %%
fraud_ge6 = []
nf_ge6 = []
for i in range(len(df)):
    if pd.isnull(df.iloc[i].GE65_Tot_Clms)== True and pd.isnull(df.iloc[i].GE65_Tot_30day_Fills)== True and pd.isnull(df.iloc[i].GE65_Tot_Drug_Cst)== True and pd.isnull(df.iloc[i].GE65_Tot_Day_Suply)== True and pd.isnull(df.iloc[i].GE65_Tot_Benes)== True and pd.isnull(df.iloc[i].Tot_Benes):
        if(df.iloc[i].Fraud == 1):
            fraud_ge6.append(i)
        else:
            nf_ge6.append(i)

# %%
print(len(fraud_ge6))
print(len(nf_ge6))
# Out:
# 97
# 66561

# %% [markdown]
# ### Without Tot_Benes

# %%
fraud_ge6_wt = []
nf_ge6_wt = []
for i in range(len(df)):
    if pd.isnull(df.iloc[i].GE65_Tot_Clms)== True and pd.isnull(df.iloc[i].GE65_Tot_30day_Fills)== True and pd.isnull(df.iloc[i].GE65_Tot_Drug_Cst)== True and pd.isnull(df.iloc[i].GE65_Tot_Day_Suply)== True and pd.isnull(df.iloc[i].GE65_Tot_Benes)== True:
        if(df.iloc[i].Fraud == 1):
            fraud_ge6_wt.append(i)
        else:
            nf_ge6_wt.append(i)

# %%
print(len(fraud_ge6_wt))
print(len(nf_ge6_wt))
# Out:
# 384
# 293722

# %%
ge6 = []
for i in range(len(df)):
    if pd.isnull(df.iloc[i].GE65_Tot_Clms)== True and pd.isnull(df.iloc[i].GE65_Tot_30day_Fills)== True and pd.isnull(df.iloc[i].GE65_Tot_Drug_Cst)== True and pd.isnull(df.iloc[i].GE65_Tot_Day_Suply)== True and pd.isnull(df.iloc[i].GE65_Tot_Benes)and pd.isnull(df.iloc[i].Tot_Benes)== True:
        ge6.append(i)

# %%
selected_columns = ["Tot_Benes","GE65_Tot_Clms","GE65_Tot_30day_Fills","GE65_Tot_Drug_Cst"]
df1_ge65 = df.drop(columns = selected_columns).copy().head(0)
df1_ge65 = pd.DataFrame(df1_ge65)
df1_ge65
# Out:
# Empty DataFrame
# Columns: [PRSCRBR_NPI, Prscrbr_Type, Tot_Clms, Tot_30day_Fills, Tot_Drug_Cst, Tot_Day_Suply, GE65_Tot_Day_Suply, GE65_Tot_Benes, Brnd_Tot_Clms, Brnd_Tot_Drug_Cst, Gnrc_Tot_Clms, Gnrc_Tot_Drug_Cst, Othr_Tot_Clms, Othr_Tot_Drug_Cst, MAPD_Tot_Clms, MAPD_Tot_Drug_Cst, PDP_Tot_Clms, PDP_Tot_Drug_Cst, LIS_Tot_Clms, LIS_Drug_Cst, NonLIS_Tot_Clms, NonLIS_Drug_Cst, Opioid_Tot_Clms, Opioid_Tot_Drug_Cst, Opioid_Tot_Suply, Opioid_Tot_Benes, Opioid_LA_Tot_Clms, Opioid_LA_Tot_Drug_Cst, Opioid_LA_Tot_Suply, Opioid_LA_Tot_Benes, Antbtc_Tot_Clms, Antbtc_Tot_Drug_Cst, Antbtc_Tot_Benes, Antpsyct_GE65_Tot_Clms, Antpsyct_GE65_Tot_Drug_Cst, Antpsyct_GE65_Tot_Benes, Fraud]
# Index: []
#
# [0 rows x 37 columns]

# %%
for i in ge6:
